# %% [markdown]
# File words_repo.json taken from https://github.com/dwyl/english-words/words_dictionary.json<br>
# File dictionary.son taken from https://raw.githubusercontent.com/adambom/dictionary/master/dictionary.json<br>
# coding: utf-8

# %% [markdown]
# In[5]:

# %%
from newspaper import Article

# %% [markdown]
# In[6]:

# %%
article = Article(url="https://www.thehindu.com/news/national/andhra-pradesh/centre-to-soon-take-up-linking-of-godavari-and-cauvery-gadkari/article26051017.ece", language='en')

# %% [markdown]
# In[9]:

# %%
article.download()

# %% [markdown]
# In[11]:

# %%
article.parse()

# %% [markdown]
# In[13]:

# %%
article.nlp()

# %% [markdown]
# In[14]:

# %%
print(article.title)

# %% [markdown]
# In[15]:

# %%
print(article.text)

# %% [markdown]
# In[16]:

# %%
print(article.summary)

# %% [markdown]
# In[17]:

# %%
print(article.authors)

# %% [markdown]
# In[18]:

# %%
print(article.keywords)

# %% [markdown]
# In[19]:

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# %% [markdown]
# In[20]:

# %%
from nltk.tokenize import word_tokenize 
tokenized_article = word_tokenize(article.text)

# %% [markdown]
# In[32]:

# %%
filtered_words = [word for word in tokenized_article if word.lower() not in stop_words and word != ('' or "" or ',' or '.')]

# %% [markdown]
# In[33]:

# %%
print(filtered_words)

# %% [markdown]
# In[58]:

# %%
with open('dictionary.json') as dictionary:
    dictionary = json.load(dictionary)

# %% [markdown]
# In[80]:

# %%
vocab = {}

# %% [markdown]
# In[82]:

# %%
for word in filtered_words:
    if word.upper() in dictionary:
        vocab[word] = dictionary[word.upper()]

# %% [markdown]
# In[83]:

# %%
print(vocab)
